# %% [markdown]
# # Example on the usage of NIMBUS
# This notebook will go through a simple example to illustrate how the synchronous variant of NIMBUS has been implemented in the DESDEO framework.
#
# We will be solving the Kursawe function originally defined in [this article](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.47.8050&rep=rep1&type=pdf)
#
# Let us begin by importing some libraries and defining the problem.

# %%
import numpy as np

import matplotlib.pyplot as plt
from desdeo_problem.Problem import MOProblem
from desdeo_problem.Variable import variable_builder
from desdeo_problem.Objective import _ScalarObjective

def f_1(xs: np.ndarray):
    xs = np.atleast_2d(xs)
    xs_plusone = np.roll(xs, 1, axis=1)
    return np.sum(-10*np.exp(-0.2*np.sqrt(xs[:, :-1]**2 + xs_plusone[:, :-1]**2)), axis=1)

def f_2(xs: np.ndarray):
    xs = np.atleast_2d(xs)
    return np.sum(np.abs(xs)**0.8 + 5*np.sin(xs**3), axis=1)


varsl = variable_builder(
    ["x_1", "x_2", "x_3"],
    initial_values=[0, 0, 0],
    lower_bounds=[-5, -5, -5],
    upper_bounds=[5, 5, 5],
)

f1 = _ScalarObjective(name="f1", evaluator=f_1)
f2 = _ScalarObjective(name="f2", evaluator=f_2)

problem = MOProblem(variables=varsl, objectives=[f1, f2], ideal=np.array([-20, -12]), nadir=np.array([-14, 0.5]))

# %% [markdown]
# To check out problem, let us compute a representation of the Pareto optimal front of solutions:

# %%
from desdeo_tools.scalarization.ASF import PointMethodASF
from desdeo_tools.scalarization.Scalarizer import Scalarizer
from desdeo_tools.solver.ScalarSolver import ScalarMinimizer, ScalarMethod

from scipy.optimize import differential_evolution

asf = PointMethodASF(problem.nadir, problem.ideal)

# TODO: Delete me and use me as an import from desdeo-tools
scipy_de_method = ScalarMethod(
    lambda x, _, **y: differential_evolution(x, **y),
    method_args={"polish": False},
)
scalarizer = Scalarizer(lambda x: problem.evaluate(x).objectives, asf, scalarizer_args={"reference_point": None})
solver = ScalarMinimizer(scalarizer, bounds=problem.get_variable_bounds(), method=scipy_de_method, constraint_evaluator=())

z_mesh = np.mgrid[problem.ideal[0]:problem.nadir[0]+0.1:1, problem.ideal[1]:problem.nadir[1]+0.1:1].reshape(2, -1).T
p_front = np.zeros(z_mesh.shape)

for i, z in enumerate(z_mesh):
    scalarizer._scalarizer_args = {"reference_point": z}
    res = solver.minimize(np.array([0, 0, 0]))
    p_front[i] = problem.evaluate(res.x).objectives

plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()
# Out:
# -Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,841 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Display' (NotoSansDisplay-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,841 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Hebrew' (NotoSansHebrew-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,842 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Mono' (DroidSansMono.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,843 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Khmer UI' (NotoSansKhmerUI-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,844 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Arabic' (NotoSansArabic-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,845 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Khmer' (NotoSerifKhmer-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,845 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Caucasian Albanian' (NotoSansCaucasianAlbanian-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,846 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'URW Gothic' (URWGothic-Book.otf) normal normal book normal>) = 10.05
# 2020-04-01 01:33:42,853 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Liberation Serif' (LiberationSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2020-04-01 01:33:42,854 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Takri' (NotoSansTakri-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,856 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bitstream Vera Serif' (VeraSe.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,856 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Malayalam' (NotoSansMalayalam-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,857 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Devanagari UI' (NotoSansDevanagariUI-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,858 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans' (NotoSans-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-01 01:33:42,859 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Liberation Serif' (LiberationSerif-Regular.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,861 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Ethiopic' (DroidSansEthiopic-Regular.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,862 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif' (NotoSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-04-01 01:33:42,863 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Ugaritic' (NotoSansUgaritic-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,864 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Myanmar UI' (NotoSansMyanmarUI-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,865 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Tirhuta' (NotoSansTirhuta-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,866 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Kannada' (NotoSansKannada-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,868 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mro' (NotoSansMro-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,868 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Georgian' (NotoSansGeorgian-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,869 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-04-01 01:33:42,870 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Gurmukhi' (NotoSerifGurmukhi-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-01 01:33:42,871 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Hebrew' (DroidSansHebrew-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,872 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Warang Citi' (NotoSansWarangCiti-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,873 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-Oblique.otf) oblique normal 400 condensed>) = 11.25
# 2020-04-01 01:33:42,873 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Canadian Aboriginal' (NotoSansCanadianAboriginal-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-01 01:33:42,874 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bitstream Vera Sans Mono' (VeraMono.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,876 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cantarell' (Cantarell-Light.otf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,876 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Devanagari' (NotoSerifDevanagari-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,877 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Gujarati' (NotoSerifGujarati-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,878 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mono' (NotoSansMono-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,878 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Khmer' (NotoSansKhmer-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,879 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Bengali UI' (NotoSansBengaliUI-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,880 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Display' (NotoSerifDisplay-ThinItalic.ttf) italic normal 400 normal>) = 11.05
# 2020-04-01 01:33:42,882 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Devanagari' (NotoSansDevanagari-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,884 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Telugu' (NotoSerifTelugu-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,884 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Malayalam' (NotoSerifMalayalam-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,885 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,886 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Armenian' (NotoSansArmenian-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,887 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Kaithi' (NotoSansKaithi-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,888 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Kannada UI' (NotoSansKannadaUI-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,889 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Sinhala' (NotoSerifSinhala-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,891 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'TSCu_Paranar' (TSCu_paranarb.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,893 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Cherokee' (NotoSansCherokee-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,894 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Armenian' (NotoSerifArmenian-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-01 01:33:42,894 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Arabic' (NotoSansArabic-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,895 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Armenian' (NotoSansArmenian-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,896 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bitstream Vera Serif' (VeraSeBd.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,897 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Biolinum O' (LinBiolinum_RB.otf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,898 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Libertine' (LinLibertine_RZah.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,899 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Devanagari' (NotoSerifDevanagari-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,900 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Bengali' (NotoSerifBengali-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,902 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Gurmukhi' (NotoSansGurmukhi-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,903 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Source Code Pro' (SourceCodePro-Bold.otf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,904 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans' (NotoSans-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,905 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Libertine O' (LinLibertine_R.otf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,906 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Libertine Initials' (LinLibertine_I.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,907 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bitstream Vera Sans' (VeraBd.ttf) normal normal 700 normal>) = 1.2440909090909091
# 2020-04-01 01:33:42,908 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Gujarati' (NotoSansGujarati-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,910 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'URW Gothic' (URWGothic-DemiOblique.otf) oblique normal demi normal>) = 11.24
# 2020-04-01 01:33:42,910 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'URW Gothic' (URWGothic-Demi.otf) normal normal demi normal>) = 10.24
# 2020-04-01 01:33:42,911 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Ethiopic' (NotoSansEthiopic-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,912 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed.ttf) normal normal 400 condensed>) = 0.25
# 2020-04-01 01:33:42,913 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Tai Le' (NotoSansTaiLe-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,914 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Linear A' (NotoSansLinearA-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,917 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2020-04-01 01:33:42,919 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Sharada' (NotoSansSharada-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,920 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Gurmukhi UI' (NotoSansGurmukhiUI-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,922 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif' (NotoSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,923 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Sinhala' (NotoSansSinhala-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,924 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Display' (NotoSerifDisplay-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,924 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Source Code Pro' (SourceCodePro-Black.otf) normal normal black normal>) = 10.525
# 2020-04-01 01:33:42,925 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Cherokee' (NotoSansCherokee-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,926 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Liberation Sans' (LiberationSans-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-04-01 01:33:42,928 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Tamil' (NotoSerifTamil-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,929 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Lao UI' (NotoSansLaoUI-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,930 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Lao UI' (NotoSansLaoUI-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,931 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Nastaliq Urdu' (NotoNastaliqUrdu-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,932 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Telugu' (NotoSansTelugu-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,933 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Khudawadi' (NotoSansKhudawadi-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,934 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Armenian' (NotoSerifArmenian-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,934 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Tamil' (NotoSerifTamil-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,936 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Tagbanwa' (NotoSansTagbanwa-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,937 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Oriya UI' (NotoSansOriyaUI-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,939 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Ogham' (NotoSansOgham-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,940 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Hebrew' (NotoSansHebrew-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,940 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Limbu' (NotoSansLimbu-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,942 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Thai' (NotoSansThai-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,943 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'TSCu_Paranar' (TSCu_Paranar.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,944 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Libertine O' (LinLibertine_RZI.otf) italic normal 700 normal>) = 11.335
# 2020-04-01 01:33:42,945 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mono' (NotoSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,946 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Source Code Pro' (SourceCodePro-Semibold.otf) normal normal semibold normal>) = 10.24
# 2020-04-01 01:33:42,947 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Hebrew' (DroidSansHebrew-Regular.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,949 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Khmer' (NotoSansKhmer-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,950 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mono' (NotoSansMono-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,952 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Display' (NotoSerifDisplay-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-01 01:33:42,953 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Fallback' (DroidSansFallbackLegacy.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,955 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Armenian' (NotoSansArmenian-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-01 01:33:42,956 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Khmer' (NotoSerifKhmer-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-01 01:33:42,960 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Naskh Shift Alt' (DroidNaskh-Regular-SystemUI.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,961 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Thaana' (NotoSansThaana-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,964 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Source Code Pro' (SourceCodePro-MediumIt.otf) italic normal medium normal>) = 11.145
# 2020-04-01 01:33:42,965 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Hebrew' (NotoSerifHebrew-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,968 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Ethiopic' (NotoSansEthiopic-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-01 01:33:42,969 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Georgian' (NotoSansGeorgian-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,971 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans' (NotoSans-Italic.ttf) italic normal 400 normal>) = 11.05
# 2020-04-01 01:33:42,972 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Phoenician' (NotoSansPhoenician-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,973 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Kannada' (NotoSansKannada-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,974 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mandaic' (NotoSansMandaic-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-01 01:33:42,975 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Bengali' (NotoSansBengali-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,976 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans' (NotoSans-LightItalic.ttf) italic normal light normal>) = 11.24
# 2020-04-01 01:33:42,977 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Myanmar' (NotoSerifMyanmar-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-01 01:33:42,978 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Sagar' (SagarNormal.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,979 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Kufi Arabic' (NotoKufiArabic-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-01 01:33:42,980 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Liberation Sans' (LiberationSans-Regular.ttf) normal normal 400 normal>) = 10.05
# 2020-04-01 01:33:42,988 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/home/kilo/.cache/pypoetry/virtualenvs/desdeo-mcdm-fREJOGIY-py3.8/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %% [markdown]
# Now we can get to the NIMBUS part. Let us define an instance of the NIMBUS method utilizing our problem defined earlier, and start by invoking the instance's `start` method:

# %%
from desdeo_mcdm.interactive.NIMBUS import NIMBUS

method = NIMBUS(problem, scipy_de_method)

classification_request, plot_request = method.start()

# %% [markdown]
# Let us look at the keys in the dictionary contained in the `classification_request`:

# %%
print(classification_request.content.keys())
# Out:
# dict_keys(['message', 'objective_values', 'classifications', 'levels', 'number_of_solutions'])

# %% [markdown]
# Message should give us some more information:

# %%
print(classification_request.content["message"])
# Out:
# Please classify each of the objective values in one of the following categories:
# 	1. values should improve '<'
# 	2. values should improve until some desired aspiration level is reached '<='
# 	3. values with an acceptable level '='
# 	4. values which may be impaired until some upper bound is reached '>='
# 	5. values which are free to change '0'
# Provide the aspiration levels and upper bounds as a vector. For categories 1, 3, and 5,the value in the vector at the objective's position is ignored. Suppy also the number of maximumsolutions to be generated.

# %% [markdown]
# We should therefore classify each of the objectives found beind the `objective_values` -key in the dictionary in `classification_request.content`. Let's print them:

# %%
print(classification_request.content["objective_values"])
# Out:
# [-15.89864825  -7.74207821]

# %% [markdown]
# Instead of printing the values, we could have also used the `plot_request` object. However, we are inspecting only one set of objective values for the time being, so a raw print of the values should be enough. Let us classify the objective values next. We can get a hint of what the classification should look like by inspecting the value found using the `classifications` -key in `classification_request.content`:

# %%
print(classification_request.content["classifications"])
# Out:
# [None]

# %% [markdown]
# Therefore it should be a list. Suppose we wish to improve (decrease in value) the first objective, and impair (increase in value) the second objective till some upper bound is reached. We should define our preferences as a dictionary `classification_request.response` with the keys `classifications` and `number_of_solutions` (we have to define the number of new solutions we wish to compute). The key `levels` will contain the upper bound for the second objective.

# %%
response = {
    "classifications": ["<", ">="],
    "number_of_solutions": 3,
    "levels": [0, -5]
}
classification_request._response = response

# %% [markdown]
# To continue, just feed `classification_request` back to the method through the `step` method:

# %%
save_request, plot_request = method.step(classification_request)
# Out:
# fine
# fine
# []
# [1]
# i'm empty
# fine impair levels
# fine

# %% [markdown]
# We got a new request as a response. Let us inspect it:

# %%
print(save_request.content.keys())
print(save_request.content["message"])
print(save_request.content["objectives"])
# Out:
# dict_keys(['message', 'solutions', 'objectives', 'indices'])
# Please specify which solutions shown you would like to save for later viewing. Supply the indices of such solutions as a list, or supply an empty list if none of the shown soulutions should be saved.
# [array([-1.99999999e+01,  1.68321206e-06]), array([-1.99999998e+01,  3.40217721e-06]), array([-18.46910322,  -1.82518345])]

# %% [markdown]
# Suppose the first and last solutions result in nice objective values.

# %%
response = {"indices": [0, 2]}
save_request._response = response

intermediate_request, plot_request = method.step(save_request)

# %%
print(intermediate_request.content.keys())
print(intermediate_request.content["message"])
# Out:
# dict_keys(['message', 'solutions', 'objectives', 'indices', 'number_of_desired_solutions'])
# Would you like to see intermediate solutions between two previusly computed solutions? If so, please supply two indices corresponding to the solutions.

# %% [markdown]
# We do not desire to see intermediate results.

# %%
response = {"number_of_desired_solutions": 0}
intermediate_request._response = response

preferred_request, plot_request = method.step(intermediate_request)

# %%
print(preferred_request.content.keys())
print(preferred_request.content["message"])
# Out:
# dict_keys(['message', 'solutions', 'objectives', 'index', 'continue'])
# Please select your most preferred solution and whether you would like to continue.

# %% [markdown]
# We should select our most preferred solution. Let us plot the objective values to inspect them better:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(preferred_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# Solutions at indices 0 and 2 seem to be overlapping in the objective space. We decide to select the solution at index 1, and to continue the iterations.

# %%
response = {"index": 1, "continue": True}
preferred_request._response = response

classification_request, plot_request = method.step(preferred_request)

# %% [markdown]
# Back at the classification pahse of the NIMBUS method.

# %%
response = {
    "classifications": [">=", "<"],
    "number_of_solutions": 4,
    "levels": [-16, -1]
}
classification_request._response = response

save_request, plot_request = method.step(classification_request)
# Out:
# fine
# fine
# []
# [0]
# i'm empty
# fine impair levels
# fine

# %% [markdown]
# Let us plot some of the solutions again:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(save_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# NIMBUS really took to heart our request to detoriate the first objective... Suppose we like all of the solutions:

# %%
response = {"indices": [0, 1, 2, 3]}
save_request._response = response

intermediate_request, plot_request = method.step(save_request)

# %% [markdown]
# Let us plot everything we have so far:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(intermediate_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# Assume we really like what we have between solution 3 and 4. Let NIMBUS compute 3 intermediate solutions between them:

# %%
response = {
    "indices": [3, 4],
    "number_of_desired_solutions": 3,
    }
intermediate_request._response = response

save_request, plot_request = method.step(intermediate_request)

# %% [markdown]
# Plot the intermediate solutions:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(save_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# Nice, we are really getting there, even if we have no goal set... Let us save solution 1:

# %%
response = {"indices": [1]}
save_request._response = response

intermediate_request, plot_request = method.step(save_request)

# %% [markdown]
# We do not wish to generate any more intermediate solutions.

# %%
response = {"number_of_desired_solutions": 0}
intermediate_request._response = response

preferred_request, plot_request = method.step(intermediate_request)

# %% [markdown]
# Let us plot everything we have, and select a final solution:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(preferred_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# We REALLY like solution 6, so let us go with that:

# %%
response = {
    "index": 6,
    "continue": False,
    }

preferred_request._response = response

print("hello")
print(preferred_request)

stop_request, plot_request = method.step(preferred_request)

print(stop_request)
# Out:
# hello
# <desdeo_mcdm.interactive.NIMBUS.NimbusMostPreferredRequest object at 0x7f0f64e98e20>
# <desdeo_mcdm.interactive.NIMBUS.NimbusStopRequest object at 0x7f0f20281970>

# %% [markdown]
# We are done, let us bask in the glory of the solution found:

# %%
print(f"Final decision variables: {stop_request.content['solution']}")

plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
plt.scatter(stop_request.content["objective"][0], stop_request.content["objective"][1], label=f"final solution")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()
# Out:
# Final decision variables: [-1.02649001 -1.09914144 -1.09961695]
