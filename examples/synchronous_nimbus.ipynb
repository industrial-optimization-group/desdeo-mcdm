# %% [markdown]
# # Example on the usage of NIMBUS
# This notebook will go through a simple example to illustrate how the synchronous variant of NIMBUS has been implemented in the DESDEO framework.
#
# We will be solving the Kursawe function originally defined in [this article](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.47.8050&rep=rep1&type=pdf)
#
# Let us begin by importing some libraries and defining the problem.

# %%
import numpy as np

import matplotlib.pyplot as plt
from desdeo_problem.Problem import MOProblem
from desdeo_problem.Variable import variable_builder
from desdeo_problem.Objective import _ScalarObjective

def f_1(xs: np.ndarray):
    xs = np.atleast_2d(xs)
    xs_plusone = np.roll(xs, 1, axis=1)
    return np.sum(-10*np.exp(-0.2*np.sqrt(xs[:, :-1]**2 + xs_plusone[:, :-1]**2)), axis=1)

def f_2(xs: np.ndarray):
    xs = np.atleast_2d(xs)
    return np.sum(np.abs(xs)**0.8 + 5*np.sin(xs**3), axis=1)


varsl = variable_builder(
    ["x_1", "x_2", "x_3"],
    initial_values=[0, 0, 0],
    lower_bounds=[-5, -5, -5],
    upper_bounds=[5, 5, 5],
)

f1 = _ScalarObjective(name="f1", evaluator=f_1)
f2 = _ScalarObjective(name="f2", evaluator=f_2)

problem = MOProblem(variables=varsl, objectives=[f1, f2], ideal=np.array([-20, -12]), nadir=np.array([-14, 0.5]))

# %% [markdown]
# To check out problem, let us compute a representation of the Pareto optimal front of solutions:

# %%
from desdeo_tools.scalarization.ASF import PointMethodASF
from desdeo_tools.scalarization.Scalarizer import Scalarizer
from desdeo_tools.solver.ScalarSolver import ScalarMinimizer, ScalarMethod

from scipy.optimize import differential_evolution

asf = PointMethodASF(problem.nadir, problem.ideal)

scalarizer = Scalarizer(lambda x: problem.evaluate(x).objectives, asf, scalarizer_args={"reference_point": None})
solver = ScalarMinimizer(scalarizer, bounds=problem.get_variable_bounds(), method="scipy_de")

z_mesh = np.mgrid[problem.ideal[0]:problem.nadir[0]+0.1:1, problem.ideal[1]:problem.nadir[1]+0.1:1].reshape(2, -1).T
p_front = np.zeros(z_mesh.shape)

for i, z in enumerate(z_mesh):
    scalarizer._scalarizer_args = {"reference_point": z}
    res = solver.minimize(np.array([0, 0, 0]))
    p_front[i] = problem.evaluate(res.x).objectives

plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()
# Out:
# -Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,732 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Display' (NotoSansDisplay-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,733 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Hebrew' (NotoSansHebrew-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,734 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Mono' (DroidSansMono.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,735 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Khmer UI' (NotoSansKhmerUI-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,736 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Arabic' (NotoSansArabic-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,739 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Khmer' (NotoSerifKhmer-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,741 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Caucasian Albanian' (NotoSansCaucasianAlbanian-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,744 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'URW Gothic' (URWGothic-Book.otf) normal normal book normal>) = 10.05
# 2020-04-05 00:45:50,745 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Liberation Serif' (LiberationSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2020-04-05 00:45:50,747 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Takri' (NotoSansTakri-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,747 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bitstream Vera Serif' (VeraSe.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,749 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Malayalam' (NotoSansMalayalam-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,750 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Devanagari UI' (NotoSansDevanagariUI-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,751 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans' (NotoSans-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-05 00:45:50,752 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Liberation Serif' (LiberationSerif-Regular.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,758 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Ethiopic' (DroidSansEthiopic-Regular.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,764 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif' (NotoSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-04-05 00:45:50,765 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Ugaritic' (NotoSansUgaritic-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,766 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Myanmar UI' (NotoSansMyanmarUI-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,766 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Tirhuta' (NotoSansTirhuta-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,767 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Kannada' (NotoSansKannada-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,768 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mro' (NotoSansMro-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,770 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Georgian' (NotoSansGeorgian-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,771 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-04-05 00:45:50,772 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Gurmukhi' (NotoSerifGurmukhi-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-05 00:45:50,773 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Hebrew' (DroidSansHebrew-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,777 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Warang Citi' (NotoSansWarangCiti-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,778 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Nimbus Sans Narrow' (NimbusSansNarrow-Oblique.otf) oblique normal 400 condensed>) = 11.25
# 2020-04-05 00:45:50,780 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Canadian Aboriginal' (NotoSansCanadianAboriginal-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-05 00:45:50,781 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bitstream Vera Sans Mono' (VeraMono.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,782 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cantarell' (Cantarell-Light.otf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,783 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Devanagari' (NotoSerifDevanagari-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,784 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Gujarati' (NotoSerifGujarati-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,784 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mono' (NotoSansMono-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,785 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Khmer' (NotoSansKhmer-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,786 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Bengali UI' (NotoSansBengaliUI-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,788 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Display' (NotoSerifDisplay-ThinItalic.ttf) italic normal 400 normal>) = 11.05
# 2020-04-05 00:45:50,789 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Devanagari' (NotoSansDevanagari-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,790 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Telugu' (NotoSerifTelugu-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,792 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Malayalam' (NotoSerifMalayalam-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,793 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,794 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Armenian' (NotoSansArmenian-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,795 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Kaithi' (NotoSansKaithi-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,796 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Kannada UI' (NotoSansKannadaUI-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,797 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Sinhala' (NotoSerifSinhala-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,798 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'TSCu_Paranar' (TSCu_paranarb.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,799 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Cherokee' (NotoSansCherokee-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,800 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Armenian' (NotoSerifArmenian-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-05 00:45:50,801 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Arabic' (NotoSansArabic-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,802 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Armenian' (NotoSansArmenian-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,803 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bitstream Vera Serif' (VeraSeBd.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,804 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Biolinum O' (LinBiolinum_RB.otf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,805 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Libertine' (LinLibertine_RZah.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,814 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Devanagari' (NotoSerifDevanagari-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,815 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Bengali' (NotoSerifBengali-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,815 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Gurmukhi' (NotoSansGurmukhi-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,816 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Source Code Pro' (SourceCodePro-Bold.otf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,817 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans' (NotoSans-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,819 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Libertine O' (LinLibertine_R.otf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,819 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Libertine Initials' (LinLibertine_I.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,820 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bitstream Vera Sans' (VeraBd.ttf) normal normal 700 normal>) = 1.2440909090909091
# 2020-04-05 00:45:50,821 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Gujarati' (NotoSansGujarati-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,821 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'URW Gothic' (URWGothic-DemiOblique.otf) oblique normal demi normal>) = 11.24
# 2020-04-05 00:45:50,822 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'URW Gothic' (URWGothic-Demi.otf) normal normal demi normal>) = 10.24
# 2020-04-05 00:45:50,824 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Ethiopic' (NotoSansEthiopic-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,826 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed.ttf) normal normal 400 condensed>) = 0.25
# 2020-04-05 00:45:50,827 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Tai Le' (NotoSansTaiLe-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,828 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Linear A' (NotoSansLinearA-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,829 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2020-04-05 00:45:50,830 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Sharada' (NotoSansSharada-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,831 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Gurmukhi UI' (NotoSansGurmukhiUI-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,832 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif' (NotoSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,833 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Sinhala' (NotoSansSinhala-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,834 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Display' (NotoSerifDisplay-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,835 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Source Code Pro' (SourceCodePro-Black.otf) normal normal black normal>) = 10.525
# 2020-04-05 00:45:50,836 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Cherokee' (NotoSansCherokee-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,836 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Liberation Sans' (LiberationSans-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-04-05 00:45:50,838 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Tamil' (NotoSerifTamil-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,843 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Lao UI' (NotoSansLaoUI-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,844 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Lao UI' (NotoSansLaoUI-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,845 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Nastaliq Urdu' (NotoNastaliqUrdu-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,847 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Telugu' (NotoSansTelugu-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,848 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Khudawadi' (NotoSansKhudawadi-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,848 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Armenian' (NotoSerifArmenian-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,849 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Tamil' (NotoSerifTamil-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,850 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Tagbanwa' (NotoSansTagbanwa-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,851 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Oriya UI' (NotoSansOriyaUI-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,851 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Ogham' (NotoSansOgham-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,852 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Hebrew' (NotoSansHebrew-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,853 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Limbu' (NotoSansLimbu-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,854 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Thai' (NotoSansThai-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,857 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'TSCu_Paranar' (TSCu_Paranar.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,860 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Linux Libertine O' (LinLibertine_RZI.otf) italic normal 700 normal>) = 11.335
# 2020-04-05 00:45:50,861 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mono' (NotoSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,862 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Source Code Pro' (SourceCodePro-Semibold.otf) normal normal semibold normal>) = 10.24
# 2020-04-05 00:45:50,863 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Hebrew' (DroidSansHebrew-Regular.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,864 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Khmer' (NotoSansKhmer-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,865 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mono' (NotoSansMono-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,866 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Display' (NotoSerifDisplay-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-05 00:45:50,867 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Sans Fallback' (DroidSansFallbackLegacy.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,867 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Armenian' (NotoSansArmenian-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-05 00:45:50,868 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Khmer' (NotoSerifKhmer-Black.ttf) normal normal black normal>) = 10.525
# 2020-04-05 00:45:50,869 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Droid Naskh Shift Alt' (DroidNaskh-Regular-SystemUI.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,870 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Thaana' (NotoSansThaana-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,871 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Source Code Pro' (SourceCodePro-MediumIt.otf) italic normal medium normal>) = 11.145
# 2020-04-05 00:45:50,872 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Hebrew' (NotoSerifHebrew-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,873 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Ethiopic' (NotoSansEthiopic-Light.ttf) normal normal light normal>) = 10.24
# 2020-04-05 00:45:50,875 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Georgian' (NotoSansGeorgian-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,876 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans' (NotoSans-Italic.ttf) italic normal 400 normal>) = 11.05
# 2020-04-05 00:45:50,876 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Phoenician' (NotoSansPhoenician-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,877 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Kannada' (NotoSansKannada-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,878 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Mandaic' (NotoSansMandaic-Regular.ttf) normal normal regular normal>) = 10.05
# 2020-04-05 00:45:50,879 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans Bengali' (NotoSansBengali-Thin.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,880 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Sans' (NotoSans-LightItalic.ttf) italic normal light normal>) = 11.24
# 2020-04-05 00:45:50,881 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Serif Myanmar' (NotoSerifMyanmar-Medium.ttf) normal normal medium normal>) = 10.145
# 2020-04-05 00:45:50,884 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Sagar' (SagarNormal.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,885 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Noto Kufi Arabic' (NotoKufiArabic-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-04-05 00:45:50,885 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Liberation Sans' (LiberationSans-Regular.ttf) normal normal 400 normal>) = 10.05
# 2020-04-05 00:45:50,886 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/home/kilo/.cache/pypoetry/virtualenvs/desdeo-mcdm-fREJOGIY-py3.8/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %% [markdown]
# Now we can get to the NIMBUS part. Let us define an instance of the NIMBUS method utilizing our problem defined earlier, and start by invoking the instance's `start` method:

# %%
from desdeo_mcdm.interactive.NIMBUS import NIMBUS

method = NIMBUS(problem, "scipy_de")

classification_request, plot_request = method.start()

# %% [markdown]
# Let us look at the keys in the dictionary contained in the `classification_request`:

# %%
print(classification_request.content.keys())
# Out:
# dict_keys(['message', 'objective_values', 'classifications', 'levels', 'number_of_solutions'])

# %% [markdown]
# Message should give us some more information:

# %%
print(classification_request.content["message"])
# Out:
# Please classify each of the objective values in one of the following categories:
# 	1. values should improve '<'
# 	2. values should improve until some desired aspiration level is reached '<='
# 	3. values with an acceptable level '='
# 	4. values which may be impaired until some upper bound is reached '>='
# 	5. values which are free to change '0'
# Provide the aspiration levels and upper bounds as a vector. For categories 1, 3, and 5,the value in the vector at the objective's position is ignored. Suppy also the number of maximumsolutions to be generated.

# %% [markdown]
# We should therefore classify each of the objectives found beind the `objective_values` -key in the dictionary in `classification_request.content`. Let's print them:

# %%
print(classification_request.content["objective_values"])
# Out:
# [-15.66192667  -7.69598607]

# %% [markdown]
# Instead of printing the values, we could have also used the `plot_request` object. However, we are inspecting only one set of objective values for the time being, so a raw print of the values should be enough. Let us classify the objective values next. We can get a hint of what the classification should look like by inspecting the value found using the `classifications` -key in `classification_request.content`:

# %%
print(classification_request.content["classifications"])
# Out:
# [None]

# %% [markdown]
# Therefore it should be a list. Suppose we wish to improve (decrease in value) the first objective, and impair (increase in value) the second objective till some upper bound is reached. We should define our preferences as a dictionary `classification_request.response` with the keys `classifications` and `number_of_solutions` (we have to define the number of new solutions we wish to compute). The key `levels` will contain the upper bound for the second objective.

# %%
response = {
    "classifications": ["<", ">="],
    "number_of_solutions": 3,
    "levels": [0, -5]
}
classification_request.response = response

# %% [markdown]
# To continue, just feed `classification_request` back to the method through the `step` method:

# %%
save_request, plot_request = method.step(classification_request)

# %% [markdown]
# We got a new request as a response. Let us inspect it:

# %%
print(save_request.content.keys())
print(save_request.content["message"])
print(save_request.content["objectives"])
# Out:
# dict_keys(['message', 'solutions', 'objectives', 'indices'])
# Please specify which solutions shown you would like to save for later viewing. Supply the indices of such solutions as a list, or supply an empty list if none of the shown soulutions should be saved.
# [array([-1.99999999e+01,  2.57477266e-06]), array([-1.99999999e+01,  2.39775870e-06]), array([-18.46923077,  -1.82215091])]

# %% [markdown]
# Suppose the first and last solutions result in nice objective values.

# %%
response = {"indices": [0, 2]}
save_request.response = response

intermediate_request, plot_request = method.step(save_request)

# %%
print(intermediate_request.content.keys())
print(intermediate_request.content["message"])
# Out:
# dict_keys(['message', 'solutions', 'objectives', 'indices', 'number_of_desired_solutions'])
# Would you like to see intermediate solutions between two previusly computed solutions? If so, please supply two indices corresponding to the solutions.

# %% [markdown]
# We do not desire to see intermediate results.

# %%
response = {"number_of_desired_solutions": 0, "indices": []}
intermediate_request.response = response

preferred_request, plot_request = method.step(intermediate_request)

# %%
print(preferred_request.content.keys())
print(preferred_request.content["message"])
# Out:
# dict_keys(['message', 'solutions', 'objectives', 'index', 'continue'])
# Please select your most preferred solution and whether you would like to continue.

# %% [markdown]
# We should select our most preferred solution. Let us plot the objective values to inspect them better:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(preferred_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# Solutions at indices 0 and 2 seem to be overlapping in the objective space. We decide to select the solution at index 1, and to continue the iterations.

# %%
response = {"index": 1, "continue": True}
preferred_request.response = response

classification_request, plot_request = method.step(preferred_request)

# %% [markdown]
# Back at the classification pahse of the NIMBUS method.

# %%
response = {
    "classifications": [">=", "<"],
    "number_of_solutions": 4,
    "levels": [-16, -1]
}
classification_request.response = response

save_request, plot_request = method.step(classification_request)

# %% [markdown]
# Let us plot some of the solutions again:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(save_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# NIMBUS really took to heart our request to detoriate the first objective... Suppose we like all of the solutions:

# %%
response = {"indices": [0, 1, 2, 3]}
save_request.response = response

intermediate_request, plot_request = method.step(save_request)

# %% [markdown]
# Let us plot everything we have so far:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(intermediate_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# Assume we really like what we have between solution 3 and 4. Let NIMBUS compute 3 intermediate solutions between them:

# %%
response = {
    "indices": [3, 4],
    "number_of_desired_solutions": 3,
    }
intermediate_request.response = response

save_request, plot_request = method.step(intermediate_request)

# %% [markdown]
# Plot the intermediate solutions:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(save_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# Nice, we are really getting there, even if we have no goal set... Let us save solution 1:

# %%
response = {"indices": [1]}
save_request.response = response

intermediate_request, plot_request = method.step(save_request)

# %% [markdown]
# We do not wish to generate any more intermediate solutions.

# %%
response = {"number_of_desired_solutions": 0, "indices": []}
intermediate_request.response = response

preferred_request, plot_request = method.step(intermediate_request)

# %% [markdown]
# Let us plot everything we have, and select a final solution:

# %%
plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
for i, z in enumerate(preferred_request.content["objectives"]):
    plt.scatter(z[0], z[1], label=f"solution {i}")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()

# %% [markdown]
# We REALLY like solution 6, so let us go with that:

# %%
response = {
    "index": 6,
    "continue": False,
    }

preferred_request.response = response

print("hello")
print(preferred_request)

stop_request, plot_request = method.step(preferred_request)

print(stop_request)
# Out:
# hello
# <desdeo_mcdm.interactive.NIMBUS.NimbusMostPreferredRequest object at 0x7fa0002fcd60>
# <desdeo_mcdm.interactive.NIMBUS.NimbusStopRequest object at 0x7f9fb9de6ca0>

# %% [markdown]
# We are done, let us bask in the glory of the solution found:

# %%
print(f"Final decision variables: {stop_request.content['solution']}")

plt.scatter(p_front[:, 0], p_front[:, 1], label="Pareto front")
plt.scatter(problem.ideal[0], problem.ideal[1], label="Ideal")
plt.scatter(problem.nadir[0], problem.nadir[1], label="Nadir")
plt.scatter(stop_request.content["objective"][0], stop_request.content["objective"][1], label=f"final solution")
plt.xlabel("f1")
plt.ylabel("f2")
plt.title("Approximate Pareto front of the Kursawe function")
plt.legend()
plt.show()
# Out:
# Final decision variables: [-1.02494646 -1.09968113 -1.09936926]
